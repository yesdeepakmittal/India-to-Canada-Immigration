# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)   #skipfooter skips rows at the end(default = 0)

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
# Type        195 non-null object
# Coverage    195 non-null object
# OdName      195 non-null object
# AREA        195 non-null int64
# AreaName    195 non-null object
# REG         195 non-null int64
# RegName     195 non-null object
# DEV         195 non-null int64
# DevName     195 non-null object
# 1980        195 non-null int64
# 1981        195 non-null int64
# 1982        195 non-null int64
# 1983        195 non-null int64
# 1984        195 non-null int64
# 1985        195 non-null int64
# 1986        195 non-null int64
# 1987        195 non-null int64
# 1988        195 non-null int64
# 1989        195 non-null int64
# 1990        195 non-null int64
# 1991        195 non-null int64
# 1992        195 non-null int64
# 1993        195 non-null int64
# 1994        195 non-null int64
# 1995        195 non-null int64
# 1996        195 non-null int64
# ...

# %%
df.columns.values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013], dtype=object)

# %%
df.shape
# Out:
# (195, 43)

# %%
df.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# %%
df.head()
# Out:
#            OdName AreaName          RegName  ...  2011  2012  2013
# 0     Afghanistan     Asia    Southern Asia  ...  2203  2635  2004
# 1         Albania   Europe  Southern Europe  ...   539   620   603
# 2         Algeria   Africa  Northern Africa  ...  4325  3774  4331
# 3  American Samoa  Oceania        Polynesia  ...     0     0     0
# 4         Andorra   Europe  Southern Europe  ...     0     1     1
#
# [5 rows x 38 columns]

# %%
df['Total']= df.sum(axis=1)

# %%
df.head()
# Out:
#            OdName AreaName          RegName  ...  2012  2013  Total
# 0     Afghanistan     Asia    Southern Asia  ...  2635  2004  58639
# 1         Albania   Europe  Southern Europe  ...   620   603  15699
# 2         Algeria   Africa  Northern Africa  ...  3774  4331  69439
# 3  American Samoa  Oceania        Polynesia  ...     0     0      6
# 4         Andorra   Europe  Southern Europe  ...     1     1     15
#
# [5 rows x 39 columns]

# %%
df.isnull().sum()
# Out:
# OdName      0
# AreaName    0
# RegName     0
# DevName     0
# 1980        0
# 1981        0
# 1982        0
# 1983        0
# 1984        0
# 1985        0
# 1986        0
# 1987        0
# 1988        0
# 1989        0
# 1990        0
# 1991        0
# 1992        0
# 1993        0
# 1994        0
# 1995        0
# 1996        0
# 1997        0
# 1998        0
# 1999        0
# 2000        0
# 2001        0
# 2002        0
# 2003        0
# 2004        0
# 2005        0
# 2006        0
# 2007        0
# 2008        0
# 2009        0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# Total       0
# dtype: int64

# %%
df.describe()
# Out:
#                1980          1981  ...          2013          Total
# count    195.000000    195.000000  ...    195.000000     195.000000
# mean     508.394872    566.989744  ...   1320.702564   32867.451282
# std     1949.588546   2152.643752  ...   4237.951988   91785.498686
# min        0.000000      0.000000  ...      0.000000       1.000000
# 25%        0.000000      0.000000  ...     45.000000     952.000000
# 50%       13.000000     10.000000  ...    213.000000    5018.000000
# 75%      251.500000    295.500000  ...    796.000000   22239.500000
# max    22045.000000  24796.000000  ...  34129.000000  691904.000000
#
# [8 rows x 35 columns]

# %%
df.rename(columns={'OdName':'Country'},inplace = True)
df.set_index('Country',inplace=True)

# %%
df.index.name=None

# %%
df.head()
# Out:
#                AreaName          RegName             DevName  ...  2012  2013  Total
# Afghanistan        Asia    Southern Asia  Developing regions  ...  2635  2004  58639
# Albania          Europe  Southern Europe   Developed regions  ...   620   603  15699
# Algeria          Africa  Northern Africa  Developing regions  ...  3774  4331  69439
# American Samoa  Oceania        Polynesia  Developing regions  ...     0     0      6
# Andorra          Europe  Southern Europe   Developed regions  ...     1     1     15
#
# [5 rows x 38 columns]

# %%
df.loc['India']
# Out:
# AreaName                  Asia
# RegName          Southern Asia
# DevName     Developing regions
# 1980                      8880
# 1981                      8670
# 1982                      8147
# 1983                      7338
# 1984                      5704
# 1985                      4211
# 1986                      7150
# 1987                     10189
# 1988                     11522
# 1989                     10343
# 1990                     12041
# 1991                     13734
# 1992                     13673
# 1993                     21496
# 1994                     18620
# 1995                     18489
# 1996                     23859
# 1997                     22268
# 1998                     17241
# 1999                     18974
# 2000                     28572
# 2001                     31223
# 2002                     31889
# 2003                     27155
# 2004                     28235
# 2005                     36210
# 2006                     33848
# ...

# %%
df.loc['India'].index
# Out:
# Index(['AreaName',  'RegName',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013,    'Total'],
#       dtype='object')

# %%
df.index.get_loc('India')
# Out:
# 79

# %%
df.iloc[79]
# Out:
# AreaName                  Asia
# RegName          Southern Asia
# DevName     Developing regions
# 1980                      8880
# 1981                      8670
# 1982                      8147
# 1983                      7338
# 1984                      5704
# 1985                      4211
# 1986                      7150
# 1987                     10189
# 1988                     11522
# 1989                     10343
# 1990                     12041
# 1991                     13734
# 1992                     13673
# 1993                     21496
# 1994                     18620
# 1995                     18489
# 1996                     23859
# 1997                     22268
# 1998                     17241
# 1999                     18974
# 2000                     28572
# 2001                     31223
# 2002                     31889
# 2003                     27155
# 2004                     28235
# 2005                     36210
# 2006                     33848
# ...

# %%
df.columns.get_loc(2013)
# Out:
# 36

# %%
df.iloc[79,[35,36]]          #for 2012 and 2013
# Out:
# 2012    30933
# 2013    33087
# Name: India, dtype: object

# %%
df.columns = list(map(str,df.columns))

# %%
ty = [type(i) for i in df.columns]
print(ty)

#ty = pd.DataFrame(ty)
#df.unique(ty.loc[0])
# Out:
# [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]

# %%
import matplotlib as mpl
print(plt.style.available)
mpl.style.use(['tableau-colorblind10'])
# Out:
# ['_classic_test', 'seaborn-poster', 'Solarize_Light2', 'seaborn-paper', 'seaborn-talk', 'seaborn-muted', 'seaborn-dark', 'seaborn-white', 'bmh', 'fivethirtyeight', 'seaborn-deep', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn', 'dark_background', 'classic', 'tableau-colorblind10', 'seaborn-notebook', 'seaborn-pastel', 'seaborn-whitegrid', 'ggplot', 'seaborn-darkgrid', 'fast', 'seaborn-ticks', 'seaborn-bright', 'grayscale']

# %%
years = list(map(str, range(1980,2014)))

# %%
India = df.loc['India',years]
India.head()
# Out:
# 1980    8880
# 1981    8670
# 1982    8147
# 1983    7338
# 1984    5704
# Name: India, dtype: object

# %%
_ = India.plot()
plt.title('Immigration from India to Canada')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.text(15, 10000, 'Total Immigrants : ' + str(df.loc['India','Total'])) #Since the year is string we have specified 15 as an index otherwise it should be 1500 for integer years
plt.show()
